# %%
# Ở bước này, các bạn import các thư viện cần thiết cho quá trình tạo nên con trợ lý ảo nhá. Các bạn nào chạy mà bị lỗi thì lên Google search cách tải thư viện cho python nha.
import ctypes
import datetime
import json
import os
import re
import smtplib
import sys
import time
import urllib
import urllib.request as urllib2
import webbrowser
from datetime import date, datetime
from time import strftime

import playsound
import requests
import speech_recognition
import speech_recognition as sr
import wikipedia
from gtts import gTTS
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from youtube_search import YoutubeSearch

# Khúc này là khai báo các biến cho quá trình làm con Alex
wikipedia.set_lang('vi')
language = 'vi'
s=Service(ChromeDriverManager().install())
robot_ear = speech_recognition.Recognizer()


# Text - to - speech: Chuyển đổi văn bản thành giọng nói
def speak(text):
    print("Bot: {}".format(text))
    tts = gTTS(text=text, lang=language, slow= False)
    filename=r'D:\hoctap\trolyao\sound.mp3'
    tts.save(filename)
    playsound.playsound(filename, False)
    os.remove(filename)


# Speech - to - text: Chuyển đổi giọng nói bạn yêu cầu vào thành văn bản hiện ra khi máy trả lại kết quả đã nghe
def get_audio():
    print("\nBot: \tĐang nghe \t *__^ \n")
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Tôi: ", end='')
        audio = r.listen(source, phrase_time_limit=8)
        try:
            text = r.recognize_google(audio, language="vi-VN")
            print(text)
            return text.lower()
        except:
            print("...")
            return 0


# Ở dòng này, Bot sẽ chào tạm biệt bạn khi bạn tạm biệt nó ^^ 
def stop():
    speak("Hẹn gặp lại bạn sau!")


# Khúc này Alex sẽ hỏi lại những gì mà bạn nói vào nhưng Alex không nghe rõ do bị dính tạp âm
def get_text():
    for i in range(3):
        text = get_audio()
        if text:
            return text.lower()
        elif i < 2:
            speak("Máy không nghe rõ. Bạn nói lại được không!")
            time.sleep(3)
    time.sleep(2)
    stop()
    return 0


# Ở đây là bước chào hỏi. Alex sẽ phân vùng thời gian để trò chuyện với bạn cho hợp lý nha ^^
def hello(name):
    day_time = int(strftime('%H'))
    if day_time < 12:
        speak("Chào buổi sáng bạn {}. Chúc bạn một ngày tốt lành.".format(name))
    elif 12 <= day_time < 18:
        speak("Chào buổi chiều bạn {}. Bạn đã dự định gì cho chiều nay chưa.".format(name))
    else:
        speak("Chào buổi tối bạn {}. Bạn đã ăn tối chưa nhỉ.".format(name))
    time.sleep(5)


# Alex đang trả lời bạn về thời gian và ngày tháng nè.
def get_time(text):
    now = date.today()
    now = datetime.today() 
    if "giờ" in text:
        speak('Bây giờ là %d giờ %d phút %d giây' % (now.hour, now.minute, now.second))
    elif "ngày" in text:
        speak("Hôm nay là ngày %d tháng %d năm %d" %
              (now.day, now.month, now.year))
    else:
        speak("Bot chưa hiểu ý của bạn. Bạn nói lại được không?")
    time.sleep(4)


# Ai mà lười kích đúp chuột để mở ứng dụng thì gọi Alex lên nhoa :3
def open_application(text):
    if "google" in text:
        speak("Mở Google Chrome")
        time.sleep(2)
        os.startfile("C:\\Users\\Public\\Desktop\\Google Chrome.lnk") # Trong ngoặc là đường dẫn đến ứng dụng trong máy mình, các bạn tự tìm trong máy mình sao cho đúng nha
    elif "steam" in text:
        speak("Mở Steam") 
        time.sleep(2)
        os.startfile("C:\\Users\\Public\\Desktop\\Steam.lnk") # Ở đây cũng như ở trên
    elif "garena" in text:
        speak("Mở Garena")
        time.sleep(2)
        os.startfile("C:\\Users\\Public\\Desktop\\Garena.lnk") # Ở trển cũng giống dưới này =))
    else:
        speak("Ứng dụng chưa được cài đặt. Bạn hãy thử lại!")
        time.sleep(3)


# Alex mở web cho bạn được luôn nè
def open_website(text):
    reg_ex = re.search('mở (.+)', text)
    if reg_ex:
        domain = reg_ex.group(1)
        url = 'https://www.' + domain
        webbrowser.open(url)
        speak("Trang web bạn yêu cầu đã được mở.")
        time.sleep(3)
        return True
    else:
        return False


# Muốn kiếm chị Google mà ngại tiếp xúc với chị ấy thì nhờ Alex nói giùm ha ^^
def open_google_and_search(text):
    search_for = text.split("kiếm", 1)[1]
    speak('Okay!')
    driver = webdriver.Chrome(service=s)
    driver.maximize_window()
    driver.get("http://www.google.com")
    que = driver.find_element(By.NAME, 'q')
    que.send_keys(str(search_for))
    que.send_keys(Keys.RETURN);
    time.sleep(10)


# Alex còn biết gửi mail mà không cần bật gmail á, thấy giỏi hôn nè ^^
def send_email(text):
    speak('Bạn gửi email cho ai nhỉ')
    recipient = get_text()
    if 'nghĩa' in recipient: # 'nghĩa' ở đây là keywords để máy tiếp tục gửi email cho bạn. Bạn có thể thay cái keywords này
        speak('Nội dung bạn muốn gửi là gì')
        content = get_text()
        mail = smtplib.SMTP('smtp.gmail.com', 587)
        mail.ehlo()
        mail.starttls()
        mail.login('nghivu147@gmail.com', 'nghivu3017') # 'xyz' ở đây là địa chỉ email của bạn (địa chỉ email gửi), 'abc' là mật khẩu của email đó
        mail.sendmail('nghivu147@gmail.com', 'yuyi2k1@gmail.com', content.encode('utf-8')) # 'xyz' ở đây cũng như bên trên, nhưng '123' là địa chỉ email nhận (email được bạn gửi thư)
        mail.close()
        speak('Email của bạn vùa được gửi. Bạn check lại email nhé hihi.')
    else:
        speak('Bot không hiểu bạn muốn gửi email cho ai. Bạn nói lại được không')


# Muốn đi chơi mà sợ trời mưa thì hãy xem dự báo thời tiết nha, nhớ gọi Alex đó

def current_weather():
    speak("Bạn muốn xem thời tiết ở đâu ạ.")
    time.sleep(5)
    ow_url = "http://api.openweathermap.org/data/2.5/weather?"
    city = get_text()
    if not city:
        pass
    api_key = "fe8d8c65cf345889139d8e545f57819a"
    call_url = ow_url + "appid=" + api_key + "&q=" + city + "&units=metric"
    response = requests.get(call_url)
    data = response.json()
    if data["cod"] != "404":
        city_res = data["main"]
        current_temperature = city_res["temp"]
        current_pressure = city_res["pressure"]
        current_humidity = city_res["humidity"]
        suntime = data["sys"]
        sunrise = datetime.fromtimestamp(suntime["sunrise"])
        sunset = datetime.fromtimestamp(suntime["sunset"])
        wthr = data["weather"]
        weather_description = wthr[0]["description"]
        now = datetime.now()
        content = """
        Hôm nay là ngày {day} tháng {month} năm {year}
        Mặt trời mọc vào {hourrise} giờ {minrise} phút
        Mặt trời lặn vào {hourset} giờ {minset} phút
        Nhiệt độ trung bình là {temp} độ C
        Áp suất không khí là {pressure} héc tơ Pascal
        Độ ẩm là {humidity}%""".format(day = now.day,month = now.month, year= now.year, hourrise = sunrise.hour,
                                       minrise = sunrise.minute,
                                       hourset = sunset.hour, minset = sunset.minute,
                                       temp = current_temperature, pressure = current_pressure, humidity = current_humidity)
        speak(content)
        time.sleep(20)
    else:
        speak("Không tìm thấy địa chỉ của bạn")

#Relax hôn, nghe nhạc trên Youtube nè ^^
def play_song():
    speak('Xin mời bạn chọn tên bài hát')
    time.sleep(2)
    mysong = get_text()
    while True:
        result = YoutubeSearch(mysong, max_results=10).to_dict()
        if result:
            break
    url = 'https://www.youtube.com' + result[0]['url_suffix']
    webbrowser.open(url)
    speak("Bài hát bạn yêu cầu đã được mở.")
    time.sleep(3)


# Không biết dạo này tình hình Cô Vy như thế nào rồi nhỉ, đọc báo phát xem thử nào :)
def read_news():
    speak("Bạn muốn đọc báo về gì")
    time.sleep(5)
    queue = get_text()
    params = {
        'apiKey': '30d02d187f7140faacf9ccd27a1441ad',
        "q": queue,
    }
    api_result = requests.get('http://newsapi.org/v2/top-headlines?', params)
    api_response = api_result.json()
    print("Tin tức")

    for number, result in enumerate(api_response['articles'], start=1):
        print(f"""Tin {number}:\nTiêu đề: {result['title']}\nTrích dẫn: {result['description']}\nLink: {result['url']}
    """)
        if number <= 3:
            webbrowser.open(result['url'])


# Hình nền máy tính bạn liệu có quá nhàm chán, hãy đổi ngay với Alex nhá
def change_wallpaper():
    api_key = 'RF3LyUUIyogjCpQwlf-zjzCf1JdvRwb--SLV6iCzOxw'
    url = 'https://api.unsplash.com/photos/random?client_id=' + \
        api_key  
    f = urllib2.urlopen(url)
    json_string = f.read()
    f.close()
    parsed_json = json.loads(json_string)
    photo = parsed_json['urls']['full']
    # Nhớ đưa cái đường dẫn của mấy tấm ảnh nền mà bạn muốn thay đổi vào nha ^^
    urllib2.urlretrieve(photo, r"C:\Users\ASUS\Pictures\lienminh.jpg")
    image=os.path.join(r"C:\Users\ASUS\Pictures\lienminh.jpg")
    ctypes.windll.user32.SystemParametersInfoW(20,0,image,3)
    speak('Hình nền máy tính vừa được thay đổi')
    time.sleep(3)


# Bật mí là con Bot này rất rất là "nhiều chuyện". Nên hổng biết cái gì cứ hỏi nó nha ^^
def tell_me_about():
    try:
        speak("Bạn muốn nghe về gì ạ")
        time.sleep(2)
        text = get_text()
        contents = wikipedia.summary(text).split('\n')
        speak(contents[0].split(".")[0])
        time.sleep(15)
        for content in contents[1:]:
            speak("Bạn muốn nghe thêm không")
            time.sleep(3)
            ans = get_text()
            if "có" not in ans:
                break    
            speak(content)
            time.sleep(15)

        speak('Cảm ơn bạn đã lắng nghe!!!')
        time.sleep(3)
    except:
        speak("Bot không định nghĩa được thuật ngữ của bạn. Xin mời bạn nói lại")
        time.sleep(5)

# Khúc này là tự bạch của Alex. Bạn có thể thay đổi cái nội dung bên trong tùy theo ý thích của bạn nha
def introduce():
    speak("bot được phát triển bởi nhóm 6 bao gồm các thành viên Vũ Thành Nghị, Bùi Minh Thái và Nguyễn Lê Đình Hiếu")
    time.sleep(8)


# Ở đây là những gì mà Alex có thể làm và đang show cái list ra cho bạn xem nè
def help_me():
    speak("""Bot tàu ngầm có thể giúp bạn thực hiện các câu lệnh sau đây:
    0. Giới thiệu bản thân
    1. Chào hỏi
    2. Hiển thị giờ
    3. Mở website, application
    4. Tìm kiếm trên Google
    5. Gửi email
    6. Dự báo thời tiết
    7. Mở video nhạc
    8. Thay đổi hình nền máy tính
    9. Đọc báo hôm nay
    10. Kể bạn biết về thế giới """)
    time.sleep(27)
                    

# Liên kết chúng lại để tạo thành con Bot Alex hoàn chỉnh thôi nào ^_^
def assistant():
    speak("Xin chào, bạn tên là gì nhỉ?")
    time.sleep(2)
    name = get_text()
    if name:
        speak("Chào bạn {}".format(name))
        speak("Bạn cần Bot tàu ngầm có thể giúp gì ạ?")
        time.sleep(3)
        while True:
            text = get_text()
            if not text:
                break
            elif "dừng" in text or "tạm biệt" in text or "ngủ thôi" in text:
                stop()
                break
            elif "có thể làm gì" in text:
                help_me()
            elif "chào" in text:
                hello(name)
            elif "giờ" in text or "ngày" in text:
                get_time(text)
            elif 'mở google và tìm kiếm' in text:
                open_google_and_search(text)
            elif "mở " in text:
                open_website(text)
            elif "ứng dụng" in text:
                speak("Tên ứng dụng bạn muốn mở là ")
                time.sleep(3)
                text1 = get_text()
                open_application(text1)
            elif "email" in text or "mail" in text or "gmail" in text:
                send_email(text)
            elif "thời tiết" in text:
                current_weather()
            elif "nghe nhạc" in text:
                play_song()
            elif "hình nền" in text:
                change_wallpaper()
            elif "đọc báo" in text:
                read_news()
            elif "định nghĩa" in text:
                tell_me_about()
            elif "giới thiệu" in text:
            	introduce()
            else:
                speak("Bạn cần Bot tàu ngầm giúp gì ạ?")
                time.sleep(2)

assistant()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [C:\Users\ASUS\.wdm\drivers\chromedriver\win32\98.0.4758.80\chromedriver.exe] found in cache
# Bot: Xin chào, bạn tên là gì nhỉ?
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: Nghịch
# Bot: Chào bạn nghịch
# Bot: Bạn cần Bot tàu ngầm có thể giúp gì ạ?
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: dự báo thời tiết
# Bot: Bạn muốn xem thời tiết ở đâu ạ.
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: Hà Nội
# Bot:
#         Hôm nay là ngày 13 tháng 2 năm 2022
#         Mặt trời mọc vào 6 giờ 28 phút
#         Mặt trời lặn vào 17 giờ 53 phút
#         Nhiệt độ trung bình là 15 độ C
#         Áp suất không khí là 1014 héc tơ Pascal
#         Độ ẩm là 80%
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: ...
# Bot: Máy không nghe rõ. Bạn nói lại được không!
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: mở video nhạc
# Bot: Trang web bạn yêu cầu đã được mở.
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: chơi nhạc
# Bot: Bạn cần Bot tàu ngầm giúp gì ạ?
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: nghe nhạc nghe nhạc
# Bot: Xin mời bạn chọn tên bài hát
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: Đổi Thay
# Bot: Bài hát bạn yêu cầu đã được mở.
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: ...
# Bot: Máy không nghe rõ. Bạn nói lại được không!
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: thay đổi hình nền
# Bot: Hình nền máy tính vừa được thay đổi
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: Đọc báo hôm nay
# Bot: Bạn muốn đọc báo về gì
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: ...
# Bot: Máy không nghe rõ. Bạn nói lại được không!
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: tình hình dịch vụ vip
# Tin tức
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: ...
# Bot: Máy không nghe rõ. Bạn nói lại được không!
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: covid 19
# Bot: Bạn cần Bot tàu ngầm giúp gì ạ?
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: đọc báo
# Bot: Bạn muốn đọc báo về gì
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: Corona
# Tin tức
# Tin 1:
# Tiêu đề: Corona weltweit: Winterspiele melden neuen Tiefststand an Infektionen
# Trích dẫn: Bei den olympischen Spielen in China sind drei weitere Ansteckungen nachgewiesen worden. Polizei in Kanada geht gegen Lkw-Blockade vor. Corona-News aus aller Welt
# Link: https://www.zeit.de/politik/ausland/2021-11/corona-weltweit-omikron-news-live
#
# Tin 2:
# Tiêu đề: COVID-19: UK monitoring hybrid delta-omicron strain called 'deltacron'
# Trích dẫn: Health officials in the United Kingdom officially began monitoring a hybrid strain of the delta and omicron coronavirus known as "deltacron" last week after it was identified in a patient in the country, according to the country's Health Security Agency.
# Link: https://www.foxnews.com/world/uk-health-officials-monitoring-hybrid-covid
#
# Tin 3:
# Tiêu đề: Olympia 2022: ARD-Experte: Neureuther hat Corona
# Trích dẫn: Jetzt hat es auch Felix Neureuther erwischt! Der Ex-Slalomstar und jetzige ARD Experte hat Corona! Sonntag wurde er per Video in die Sendung geschaltet
# Link: http://www.bild.de/sport/olympia/olympia/olympia-2022-ard-experte-neureuther-hat-corona-79132830.bild.html
#
# Tin 4:
# Tiêu đề: Canadese brug al bijna week geblokkeerd door coronademonstranten
# Trích dẫn: Canadese demonstranten blokkeren al bijna een week een brug in het land uit protest tegen de coronamaatregelen. Met hun zogenoemde vrijheidskonvooi wordt een belangrijke handelsroute met de Verenigde Staten geblokkeerd. Verder in dit liveblog: het protest van…
# Link: https://www.rtlnieuws.nl/nieuws/nederland/artikel/5287879/corona-liveblog-besmettingen-maatregelen-protest-actie-horeca
#
# Tin 5:
# Tiêu đề: Protest nachtclubs op meeste plekken rustig verlopen, fikse boete in Tilburg
# Trích dẫn: De protestactie De Nacht staat op is overwegend rustig verlopen. In meerdere steden openden nachthoreca vannacht in strijd met de coronamaatregelen hun deuren. Het was in onder andere Amsterdam, Rotterdam en Utrecht erg druk, maar voor zover bekend werd allee…
# Link: https://www.rtlnieuws.nl/nieuws/nederland/artikel/5287878/nacht-staat-op-protest-clubs-discotheken-horeca-coronamaatregelen
#
# Tin 6:
# Tiêu đề: Coronavirus à Montpellier : Une manifestation contre le pass vaccinal dégénère dans le centre-ville
# Trích dẫn: Plusieurs vitrines ont été cassées et des poubelles incendiées par une partie radicalisée des 2.500 manifestants opposés aux mesures sanitaires
# Link: https://www.20minutes.fr/societe/3234571-20220213-coronavirus-montpellier-manifestation-contre-pass-vaccinal-degenere-centre-ville
#
# Tin 7:
# Tiêu đề: Média móvel de mortes por Covid no Brasil é a maior em 6 meses e se aproxima de 900 por dia
# Trích dẫn: País tem 638.124 óbitos e 27.424.975 casos registrados do novo coronavírus, segundo dados reunidos pelo consórcio de veículos de imprensa. Média da última semana chegou a 894 vítimas diárias.
# Link: https://g1.globo.com/saude/coronavirus/noticia/2022/02/12/media-movel-de-mortes-por-covid-no-brasil-e-a-maior-em-6-meses-e-se-aproxima-de-900-por-dia.ghtml
#
# Tin 8:
# Tiêu đề: Inzidenz sinkt leicht auf 1466,5 – RKI meldet 125.160 Neuinfektionen
# Trích dẫn: Ämter registrieren 58 Todesfälle + Tausende demonstrieren gegen Coronapolitik + Faeser erinnert Söder bei Impfpflicht an das Grundgesetz + Der Newsblog.
# Link: https://www.tagesspiegel.de/wissen/coronavirus-in-deutschland-inzidenz-sinkt-leicht-auf-1466-5-rki-meldet-125-160-neuinfektionen/25560996.html
#
# Tin 9:
# Tiêu đề: Coronavirus en France : le bilan de ce samedi 12 février
# Trích dẫn: La situation tend à s'améliorer, avec des contaminations en baisse et des hospitalisations stables. Le point quotidien sur l'épidémie de Covid-19 en France, avec les chiffres de Santé Publique France et du ministère de la Santé.
# Link: https://www.cnews.fr/france/2022-02-12/coronavirus-en-france-le-bilan-de-ce-samedi-12-fevrier-1182088
#
# Tin 10:
# Tiêu đề: Die zwei großen Baustellen für Steinmeiers zweite Amtszeit
# Trích dẫn: Der Druck auf Frank-Walter-Steinmeier ist groß. Er weiß schon, welche Akzente er setzen will. Nach Corona erwartet er ein neues Konfliktthema im Land.
# Link: https://www.tagesspiegel.de/politik/was-der-bundespraesident-plant-die-zwei-grossen-baustellen-fuer-steinmeiers-zweite-amtszeit/28063746.html
#
# Tin 11:
# Tiêu đề: COVID live updates: All the coronavirus news you need in one place
# Trích dẫn: Get up to speed on all the coronavirus news from across Australia. Follow live
# Link: http://www.abc.net.au/news/2022-02-13/covid-live-blog-latest-updates-omicron-rats-boosters/100826292
#
# Tin 12:
# Tiêu đề: Truckers demonsteren in Den Haag: 'Eten mee voor een hele maand'
# Trích dẫn: In Den Haag blokkeren truckers en sympathisanten de wegen. Ze demonsteren tegen de coronamaatregelen. Sommige demonstranten zijn van plan langer te blijven: "Ik ga denk ik mijn tentje op de tramrails zetten en daar slapen".
# Link: https://www.rtlnieuws.nl/nieuws/video/video/5287791/truckers-demonsteren-den-haag-eten-mee-voor-een-hele-maand
#
# Tin 13:
# Tiêu đề: Göteborgsläkare anmäld: Skrämde patienter med coronalögner
# Trích dẫn: Rutinbesöket blev omskakande för den gravida kvinnan. Läkaren ska ha påstått att covidvaccin innehåller batterivätska och att det dödat både ofödda barn och tvåhundra piloter. Samma läkare har anmälts efter påståenden om att vaccinerna gör oss sjukare samt at…
# Link: http://www.gp.se/nyheter/g%C3%B6teborg/g%C3%B6teborgsl%C3%A4kare-anm%C3%A4ld-skr%C3%A4mde-patienter-med-coronal%C3%B6gner-1.65677754
#
# Tin 14:
# Tiêu đề: France: Police fire tear gas to stop advance of ‘Freedom Convoy’
# Trích dẫn: Some 7,000 police officers were deployed before weekend protests against coronavirus restrictions, state of economy.
# Link: http://www.aljazeera.com/news/2022/2/12/france-police-fire-tear-gas-to-stop-advance-of-freedom-convoy
#
# Tin 15:
# Tiêu đề: Corona-Impfpflicht: Polizei beginnt mit Auflösung der Trucker-Proteste in Kanada
# Trích dẫn: Seit einigen Wochen blockieren Trucker aus Protest gegen die allgemeine Impfpflicht die Zufahrt zu der kanadischen Hauptstadt Ottawa. Die Polizei beginnt nun mit der Räumung.
# Link: https://www.wiwo.de/politik/ausland/corona-impfpflicht-polizei-beginnt-mit-aufloesung-der-trucker-proteste-in-kanada/28063782.html
#
# Tin 16:
# Tiêu đề: Coronavirus oggi. L’Austria allenta le misure anti-contagio
# Trích dẫn: Cina autorizza uso condizionato pillola antivirale Pfizer La Cina ha autorizzato l’uso ’condizionato’ della pillola antivirale contro il covid di ...
# Link: https://www.ilsole24ore.com/art/coronavirus-oggi-l-austria-allenta-misure-anti-contagio-AEJetjDB
#
# Tin 17:
# Tiêu đề: Americans will be cleaning up from the coronavirus for years, experts warn
# Trích dẫn: Americans are eager for a post-omicron lull in the pandemic, but experts warn that the coronavirus isn't finished. New variants aside, the pandemic over the past two years has carved scars across society that the country hasn't begun to face.
# Link: https://www.washingtontimes.com/news/2022/feb/11/americans-will-be-cleaning-up-from-the-coronavirus/
#
# Tin 18:
# Tiêu đề: Surge in Omicron cases in Denmark and UK sends warning to rest of Europe
# Trích dẫn: Two countries show how the coronavirus variant is driving rates of infection and hospital admission
# Link: https://www.ft.com/content/3c27c135-fdbc-4db7-8c7c-6e1f6c386235
#
# Tin 19:
# Tiêu đề: Coronavirus live updates | Schools in Rajasthan to reopen from August 2
# Trích dẫn: More than half of all European adults are now fully vaccinated, the EU said on Thursday, as countries across Europe and Asia battled fresh outbreaks blamed on the fast-spreading Delta variant.
# Link: https://www.thehindu.com/news/national/coronavirus-live-july-23-2021-updates/article35481907.ece
#
# Tin 20:
# Tiêu đề: UK continues with reopening plan despite concerns
# Trích dẫn: British ministers are pushing on with a major easing of restrictions on Monday despite concerns over the Indian variant of coronavirus, as they were criticised for allowing the strain's import.
# Link: https://www.rte.ie/news/uk/2021/0515/1221764-uk-indian-variant/
#
#
# Bot: 	Đang nghe 	 *__^
# Tôi: ...
# Bot: Máy không nghe rõ. Bạn nói lại được không!
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: định nghĩa Corona
# Bot: Bạn muốn nghe về gì ạ
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: Corona
# Bot: Virus corona gây hội chứng hô hấp cấp tính nặng 2, viết tắt SARS-CoV-2 (tiếng Anh: Severe acute respiratory syndrome corona virus 2), trước đây có tên là virus corona mới 2019 (2019-nCoV) và cũng được gọi là virus corona ở người 2019 (HCoV-19 hoặc hCoV-19), là một chủng coronavirus gây ra bệnh viêm đường hô hấp cấp do virus corona 2019 (COVID-19), xuất hiện lần đầu tiên vào tháng 12 năm 2019, trong đợt bùng phát đại dịch COVID-19 ở thành phố Vũ Hán, Trung Quốc và bắt đầu lây lan nhanh chóng, sau đó trở thành một đại dịch toàn cầu
# Bot: Bạn muốn nghe thêm không
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: l virus Corona ở 10 2019 19 hoặc CoV 19
# Bot: Cảm ơn bạn đã lắng nghe!!!
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: Cô vip 19 xuất hiện lần đầu tiên vào tháng 12 năm 2019 trong đợt bùng phát đại
# Bot: Bạn cần Bot tàu ngầm giúp gì ạ?
#
# Bot: 	Đang nghe 	 *__^
#
# Tôi: tạm biệt
# Bot: Hẹn gặp lại bạn sau!
